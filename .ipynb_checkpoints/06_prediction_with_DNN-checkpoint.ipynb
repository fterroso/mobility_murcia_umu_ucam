# %% [markdown]
# # Train and test DNN models for parking space prediction

# %%
import pandas as pd
import numpy as np
import os

import tensorflow as tf
from tensorflow import keras

import matplotlib as mpl

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
target_time_period= 'july'
#target_time_period= 'sept_oct'

# %% [markdown]
# ## General functions

# %%
def read_clean_subflows_fn(critera, time_period):
    subflows= {}
    for c in critera:
        df = pd.read_csv(os.path.join('data', 'INE_subflows','flow_criterion_{}_clean_{}.csv'.format(c, time_period)),
                       parse_dates=[0], index_col=0)
        subflows[c] = df
    return subflows

# %% [markdown]
# ## Read zones 1 parking data (target variable)

# %%
zone1_df = pd.read_csv(os.path.join('data', 'parkings_JULIO', 'zone1.csv'), sep=';', parse_dates=['recvTime'], index_col='recvTime')

# %%
zone1_df.head()
# Out:
#                            free
# recvTime
# 2020-07-13 10:00:00  167.363636
# 2020-07-13 11:00:00  246.157895
# 2020-07-13 12:00:00  351.465909
# 2020-07-13 13:00:00  404.080000
# 2020-07-13 14:00:00  362.413238

# %%
zone1_df.plot(figsize=(20,3),grid=True);

# %%
target_days = zone1_df.index

# %% [markdown]
# ## Read subflows

# %%
target_criteria = range(6,11)

# %%
mob_flows = read_clean_subflows_fn(target_criteria, target_time_period)

# %% [markdown]
# ## Format data

# %%
n_steps = 12
T_ = 1

# %%
#input: flow(t), flow(t-1), ..,flow(t-prev_hours). output: parking(t+T)
def generate_univariate_time_series_fn(zone_parking, subflow, prev_hours, T=1):
    series = []
    for i in range(0,subflow.shape[0]-prev_hours-T):
        mob_values = subflow[i:i+prev_hours].values
        parking_value = zone_parking.iloc[prev_hours + i +T -1]
        s = np.append(mob_values,parking_value).reshape(-1,prev_hours+1)
        series.append(s)
    series= np.array(series)
    series = series.reshape(series.shape[0],prev_hours+1,1)
    return series

#input: flow(t), flow(t-1), ..,flow(t-prev_hours), parking(t), parking(t-1),...,
#parking(t-prev_hours),. output: parking(t+T)
def generate_univariate_time_series_fn2(zone_parking, subflow, prev_hours, T=1): 
    series = []
    for i in range(0,subflow.shape[0]-prev_hours-T):
        mob_values = subflow[i:i+prev_hours].values
        parking_values = zone_parking.iloc[i:(prev_hours + i +T -1)]
        s = np.append(mob_values,parking_values).reshape(-1,prev_hours*2)
        series.append(s)
    series= np.array(series)
    series = series.reshape(series.shape[0],prev_hours*2,1)
    return series

# %%
def generate_time_series_for_rnn_fn(zone_parking, subflow, prev_hours, T=1):
    X= []
    Y= []
    for i in range(0,subflow.shape[0]-prev_hours-T):
        mob_values = subflow[i:i+prev_hours].values
        X.append(mob_values)
        parking_values = zone_parking.iloc[i+T:i+T+prev_hours].values
        Y.append(parking_values)
    X= np.array(X)
    X = X.reshape(X.shape[0],prev_hours,1)
    
    Y= np.array(Y)
    Y = Y.reshape(Y.shape[0],prev_hours,1)
    
    return X,Y

# %% [markdown]
# ### Scale data

# %%
scaler_flow =  StandardScaler()
flow_scaled = scaler_flow.fit_transform(mob_flows[9].loc[target_days].values)
flow_scaled_df = pd.DataFrame(flow_scaled)
flow_scaled_df.head()
# Out:
#           0
# 0  1.050581
# 1  0.537342
# 2  0.377285
# 3  0.498533
# 4  1.536396

# %%
scaler_parking =  StandardScaler()
zone_scaled =scaler_parking.fit_transform(zone1_df.values)
parking_scaled_df = pd.DataFrame(zone_scaled)
parking_scaled_df.head()
# Out:
#           0
# 0 -2.046244
# 1 -1.477782
# 2 -0.718037
# 3 -0.338452
# 4 -0.639057

# %% [markdown]
# ### Generate time series samples

# %%
ts = generate_univariate_time_series_fn(parking_scaled_df, flow_scaled_df, n_steps, T_)

# %%
ts.shape
# Out:
# (433, 13, 1)

# %%
n_series = ts.shape[0]

# %% [markdown]
# ## Split training-test

# %%
training_rate = 0.9

# %%
n_series_training = round(n_series * training_rate)

# %%
X_train, y_train = ts[:n_series_training,:n_steps], ts[:n_series_training, -1]
X_valid, y_valid = ts[n_series_training:,:n_steps], ts[n_series_training:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((390, 12, 1), (390, 1))

# %%
X_valid.shape, y_valid.shape
# Out:
# ((43, 12, 1), (43, 1))

# %%
#auro
def generate_train_test(zone_parking, subflow, prev_hours, T=1, fun =1, tr= 0.9):
    if(fun==1):
        ts = generate_univariate_time_series_fn(zone_parking, subflow, n_steps, T_)
    else: 
        ts = generate_univariate_time_series_fn2(zone_parking, subflow, n_steps, T_)
    n_series = ts.shape[0]
    training_rate = tr
    n_series_training = round(n_series * training_rate)
    X_train, y_train = ts[:n_series_training,:n_steps], ts[:n_series_training, -1]
    X_valid, y_valid = ts[n_series_training:,:n_steps], ts[n_series_training:, -1]
    return X_train, y_train, X_valid, y_valid

# %% [markdown]
# ## Test DNN models

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    #plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    #plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %%
def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
def compute_metrics_fn(y_valid, y_hat, scaler):
    ## actual train and test values
    y_hat_resc = scaler_parking.inverse_transform(y_hat)
    y_valid_resc = scaler_parking.inverse_transform(y_valid)

    mae_ = mean_absolute_error(y_valid_resc, y_hat_resc)
    mse_ = mean_squared_error(y_valid_resc, y_hat_resc)
    rmse_ = mean_squared_error(y_valid_resc, y_hat_resc, squared = False)
    cvrmse_ = rmse_/np.mean(y_valid_resc)*100 # it is a percentage
    mape_ = mape(y_valid_resc, y_hat_resc)
    
    return mae_, mse_, rmse_, cvrmse_, mape_

# %%
def plot_prediction_vs_groundtruth_fn(y_valid, y_hat):
    y_hat_resc = scaler_parking.inverse_transform( y_hat[:,-1].reshape(-1,))
    y_valid_resc = scaler_parking.inverse_transform(y_valid[:,-1].reshape(-1,))
    plt.plot(np.arange(len(y_hat_resc)), y_hat_resc, "b.-", label="y_hat")
    plt.plot(np.arange(len(y_valid_resc)), y_valid_resc, "r.-", label="y_true")
    plt.legend(fontsize=14)
    plt.xlabel("Timestamp")
    plt.ylabel("Free places")
    plt.grid(True)

# %% [markdown]
# ### MLP - benchmark

# %%
import tensorflow as tf
from tensorflow import keras

# %%
np.random.seed(42)
tf.random.set_seed(42)

model_mlp = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[n_steps, 1]),
    keras.layers.Dense(1)
])

model_mlp.compile(loss="mse", optimizer="adam")
history = model_mlp.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 26ms/step - loss: 1.2167 - val_loss: 1.3824
# Epoch 2/100
# 13/13 [==============================] - 0s 7ms/step - loss: 1.1351 - val_loss: 1.2606
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0603 - val_loss: 1.1596
# Epoch 4/100
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0003 - val_loss: 1.0710
# Epoch 5/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.9568 - val_loss: 0.9869
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.9136 - val_loss: 0.9232
# Epoch 7/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8852 - val_loss: 0.8644
# Epoch 8/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8609 - val_loss: 0.8215
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8416 - val_loss: 0.7802
# Epoch 10/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8272 - val_loss: 0.7450
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8139 - val_loss: 0.7139
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8016 - val_loss: 0.6853
# Epoch 13/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7912 - val_loss: 0.6699
# Epoch 14/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7830 - val_loss: 0.6533
# Epoch 15/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7747 - val_loss: 0.6317
# Epoch 16/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7667 - val_loss: 0.6166
# Epoch 17/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7600 - val_loss: 0.6086
# Epoch 18/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7533 - val_loss: 0.6024
# Epoch 19/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7477 - val_loss: 0.5925
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7405 - val_loss: 0.5825
# Epoch 21/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7345 - val_loss: 0.5752
# Epoch 22/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7279 - val_loss: 0.5711
# Epoch 23/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7218 - val_loss: 0.5574
# Epoch 24/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7160 - val_loss: 0.5484
# Epoch 25/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7106 - val_loss: 0.5464
# Epoch 26/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7054 - val_loss: 0.5441
# Epoch 27/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7008 - val_loss: 0.5305
# Epoch 28/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6952 - val_loss: 0.5192
# Epoch 29/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6900 - val_loss: 0.5194
# Epoch 30/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6853 - val_loss: 0.5142
# Epoch 31/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6810 - val_loss: 0.5100
# Epoch 32/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6766 - val_loss: 0.5025
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6720 - val_loss: 0.4974
# Epoch 34/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6676 - val_loss: 0.4945
# Epoch 35/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6635 - val_loss: 0.4938
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6587 - val_loss: 0.4846
# Epoch 37/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6545 - val_loss: 0.4828
# Epoch 38/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6506 - val_loss: 0.4752
# Epoch 39/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6467 - val_loss: 0.4690
# Epoch 40/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6428 - val_loss: 0.4665
# Epoch 41/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6391 - val_loss: 0.4689
# Epoch 42/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6356 - val_loss: 0.4655
# Epoch 43/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6321 - val_loss: 0.4667
# Epoch 44/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6288 - val_loss: 0.4649
# Epoch 45/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6255 - val_loss: 0.4620
# Epoch 46/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6233 - val_loss: 0.4661
# Epoch 47/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6197 - val_loss: 0.4630
# Epoch 48/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6169 - val_loss: 0.4575
# Epoch 49/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6145 - val_loss: 0.4494
# Epoch 50/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6119 - val_loss: 0.4490
# Epoch 51/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6094 - val_loss: 0.4457
# Epoch 52/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6066 - val_loss: 0.4443
# Epoch 53/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6035 - val_loss: 0.4355
# Epoch 54/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6019 - val_loss: 0.4270
# Epoch 55/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5990 - val_loss: 0.4304
# Epoch 56/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5968 - val_loss: 0.4315
# Epoch 57/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5951 - val_loss: 0.4328
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5930 - val_loss: 0.4303
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5912 - val_loss: 0.4264
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5900 - val_loss: 0.4361
# Epoch 61/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5877 - val_loss: 0.4357
# Epoch 62/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5861 - val_loss: 0.4397
# Epoch 63/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5853 - val_loss: 0.4299
# Epoch 64/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5826 - val_loss: 0.4244
# Epoch 65/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5807 - val_loss: 0.4212
# Epoch 66/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5792 - val_loss: 0.4281
# Epoch 67/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5777 - val_loss: 0.4206
# Epoch 68/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5761 - val_loss: 0.4172
# Epoch 69/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5750 - val_loss: 0.4204
# Epoch 70/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5739 - val_loss: 0.4146
# Epoch 71/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5727 - val_loss: 0.4119
# Epoch 72/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5712 - val_loss: 0.4140
# Epoch 73/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5698 - val_loss: 0.4046
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5679 - val_loss: 0.4050
# Epoch 75/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5669 - val_loss: 0.4019
# Epoch 76/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5661 - val_loss: 0.4031
# Epoch 77/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5648 - val_loss: 0.4068
# Epoch 78/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5637 - val_loss: 0.4006
# Epoch 79/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5623 - val_loss: 0.3970
# Epoch 80/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5614 - val_loss: 0.4019
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5601 - val_loss: 0.4015
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5598 - val_loss: 0.3907
# Epoch 83/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5581 - val_loss: 0.3968
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5572 - val_loss: 0.4005
# Epoch 85/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5563 - val_loss: 0.3992
# Epoch 86/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5549 - val_loss: 0.4014
# Epoch 87/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5546 - val_loss: 0.4073
# Epoch 88/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5538 - val_loss: 0.4075
# Epoch 89/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5528 - val_loss: 0.4045
# Epoch 90/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5518 - val_loss: 0.3942
# Epoch 91/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5511 - val_loss: 0.3903
# Epoch 92/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5500 - val_loss: 0.3853
# Epoch 93/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5499 - val_loss: 0.3889
# Epoch 94/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5490 - val_loss: 0.3853
# Epoch 95/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5480 - val_loss: 0.3858
# Epoch 96/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5479 - val_loss: 0.3890
# Epoch 97/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5470 - val_loss: 0.3926
# Epoch 98/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5463 - val_loss: 0.3906
# Epoch 99/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5458 - val_loss: 0.3933
# Epoch 100/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5447 - val_loss: 0.3932

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_hat = model_mlp.predict(X_valid)

# %% [markdown]
# #### Get metrics

# %%
mae_, mse_, rmse_, cvrmse_, mape_ = compute_metrics_fn(y_valid, y_hat, scaler_parking)

print('MAE: {:.3f}, MSE: {:.3f}, RMSE: {:.3f}, CVRMSE: {:.3f}, MAPE: {:.3f}'.format(mae_, mse_, rmse_, cvrmse_, mape_))
# Out:
# MAE: 73.932, MSE: 7553.531, RMSE: 86.911, CVRMSE: 20.408, MAPE: 26.495

# %%
plot_prediction_vs_groundtruth_fn(y_valid, y_hat)

# %%
def mlp_benchmark(X_train, y_train, X_valid, y_valid):
    np.random.seed(42)
    tf.random.set_seed(42)

    model_mlp = keras.models.Sequential([
        keras.layers.Flatten(input_shape=[n_steps, 1]),
        keras.layers.Dense(1)
    ])

    model_mlp.compile(loss="mse", optimizer="adam")
    history = model_mlp.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid))
    plot_learning_curves(history.history["loss"], history.history["val_loss"])
    plt.show()
    y_hat = model_mlp.predict(X_valid)
    mae_, mse_, rmse_, cvrmse_, mape_ = compute_metrics_fn(y_valid, y_hat, scaler_parking)
    print('MAE: {:.3f}, MSE: {:.3f}, RMSE: {:.3f}, CVRMSE: {:.3f}, MAPE: {:.3f}'.format(mae_, mse_, rmse_, cvrmse_, mape_))
    plot_prediction_vs_groundtruth_fn(y_valid, y_hat)

# %%
# Model with flows as inputs
X_train, y_train, X_valid, y_valid = generate_train_test(parking_scaled_df, flow_scaled_df, 12, T=1)
mlp_benchmark(X_train, y_train, X_valid, y_valid)

# Model with flows and parking as inputs
X_train, y_train, X_valid, y_valid = generate_train_test(parking_scaled_df, flow_scaled_df, 
                                                         12, T=1, fun = 2)
mlp_benchmark(X_train, y_train, X_valid, y_valid)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 18ms/step - loss: 1.2167 - val_loss: 1.3824
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 1.1351 - val_loss: 1.2606
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 1.0603 - val_loss: 1.1596
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 1.0003 - val_loss: 1.0710
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.9568 - val_loss: 0.9869
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.9136 - val_loss: 0.9232
# Epoch 7/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8852 - val_loss: 0.8644
# Epoch 8/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8609 - val_loss: 0.8215
# Epoch 9/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8416 - val_loss: 0.7802
# Epoch 10/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8272 - val_loss: 0.7450
# Epoch 11/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8139 - val_loss: 0.7139
# Epoch 12/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8016 - val_loss: 0.6853
# Epoch 13/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7912 - val_loss: 0.6699
# Epoch 14/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7830 - val_loss: 0.6533
# Epoch 15/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7747 - val_loss: 0.6317
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7667 - val_loss: 0.6166
# Epoch 17/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7600 - val_loss: 0.6086
# Epoch 18/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7533 - val_loss: 0.6024
# Epoch 19/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7477 - val_loss: 0.5925
# Epoch 20/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7405 - val_loss: 0.5825
# Epoch 21/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7345 - val_loss: 0.5752
# Epoch 22/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.7279 - val_loss: 0.5711
# Epoch 23/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7218 - val_loss: 0.5574
# Epoch 24/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7160 - val_loss: 0.5484
# Epoch 25/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.7106 - val_loss: 0.5464
# Epoch 26/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7054 - val_loss: 0.5441
# Epoch 27/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.7008 - val_loss: 0.5305
# Epoch 28/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6952 - val_loss: 0.5192
# Epoch 29/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6900 - val_loss: 0.5194
# Epoch 30/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6853 - val_loss: 0.5142
# Epoch 31/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6810 - val_loss: 0.5100
# Epoch 32/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6766 - val_loss: 0.5025
# Epoch 33/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6720 - val_loss: 0.4974
# Epoch 34/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6676 - val_loss: 0.4945
# Epoch 35/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6635 - val_loss: 0.4938
# Epoch 36/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6587 - val_loss: 0.4846
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6545 - val_loss: 0.4828
# Epoch 38/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6506 - val_loss: 0.4752
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6467 - val_loss: 0.4690
# Epoch 40/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6428 - val_loss: 0.4665
# Epoch 41/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6391 - val_loss: 0.4689
# Epoch 42/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6356 - val_loss: 0.4655
# Epoch 43/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6321 - val_loss: 0.4667
# Epoch 44/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6288 - val_loss: 0.4649
# Epoch 45/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6255 - val_loss: 0.4620
# Epoch 46/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6233 - val_loss: 0.4661
# Epoch 47/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6197 - val_loss: 0.4630
# Epoch 48/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6169 - val_loss: 0.4575
# Epoch 49/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6145 - val_loss: 0.4494
# Epoch 50/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6119 - val_loss: 0.4490
# Epoch 51/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6094 - val_loss: 0.4457
# Epoch 52/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6066 - val_loss: 0.4443
# Epoch 53/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6035 - val_loss: 0.4355
# Epoch 54/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6019 - val_loss: 0.4270
# Epoch 55/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5990 - val_loss: 0.4304
# Epoch 56/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5968 - val_loss: 0.4315
# Epoch 57/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5951 - val_loss: 0.4328
# Epoch 58/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5930 - val_loss: 0.4303
# Epoch 59/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5912 - val_loss: 0.4264
# Epoch 60/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5900 - val_loss: 0.4361
# Epoch 61/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5877 - val_loss: 0.4357
# Epoch 62/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5861 - val_loss: 0.4397
# Epoch 63/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5853 - val_loss: 0.4299
# Epoch 64/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5826 - val_loss: 0.4244
# Epoch 65/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5807 - val_loss: 0.4212
# Epoch 66/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5792 - val_loss: 0.4281
# Epoch 67/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5777 - val_loss: 0.4206
# Epoch 68/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5761 - val_loss: 0.4172
# Epoch 69/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5750 - val_loss: 0.4204
# Epoch 70/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5739 - val_loss: 0.4146
# Epoch 71/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5727 - val_loss: 0.4119
# Epoch 72/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5712 - val_loss: 0.4140
# Epoch 73/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5698 - val_loss: 0.4046
# Epoch 74/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5679 - val_loss: 0.4050
# Epoch 75/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5669 - val_loss: 0.4019
# Epoch 76/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5661 - val_loss: 0.4031
# Epoch 77/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5648 - val_loss: 0.4068
# Epoch 78/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5637 - val_loss: 0.4006
# Epoch 79/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5623 - val_loss: 0.3970
# Epoch 80/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5614 - val_loss: 0.4019
# Epoch 81/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5601 - val_loss: 0.4015
# Epoch 82/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5598 - val_loss: 0.3907
# Epoch 83/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5581 - val_loss: 0.3968
# Epoch 84/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5572 - val_loss: 0.4005
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5563 - val_loss: 0.3992
# Epoch 86/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5549 - val_loss: 0.4014
# Epoch 87/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5546 - val_loss: 0.4073
# Epoch 88/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5538 - val_loss: 0.4075
# Epoch 89/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5528 - val_loss: 0.4045
# Epoch 90/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5518 - val_loss: 0.3942
# Epoch 91/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5511 - val_loss: 0.3903
# Epoch 92/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5500 - val_loss: 0.3853
# Epoch 93/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5499 - val_loss: 0.3889
# Epoch 94/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5490 - val_loss: 0.3853
# Epoch 95/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5480 - val_loss: 0.3858
# Epoch 96/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5479 - val_loss: 0.3890
# Epoch 97/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5470 - val_loss: 0.3926
# Epoch 98/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5463 - val_loss: 0.3906
# Epoch 99/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5458 - val_loss: 0.3933
# Epoch 100/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5447 - val_loss: 0.3932
# MAE: 73.932, MSE: 7553.531, RMSE: 86.911, CVRMSE: 20.408, MAPE: 26.495
# Epoch 1/100
# 13/13 [==============================] - 1s 42ms/step - loss: 1.1180 - val_loss: 1.2533
# Epoch 2/100
# 13/13 [==============================] - 0s 8ms/step - loss: 1.0306 - val_loss: 1.1216
# Epoch 3/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.9487 - val_loss: 1.0179
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.8868 - val_loss: 0.9287
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8420 - val_loss: 0.8418
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7980 - val_loss: 0.7769
# Epoch 7/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7699 - val_loss: 0.7180
# Epoch 8/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7471 - val_loss: 0.6761
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.7296 - val_loss: 0.6342
# Epoch 10/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7171 - val_loss: 0.6004
# Epoch 11/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7060 - val_loss: 0.5755
# Epoch 12/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6967 - val_loss: 0.5510
# Epoch 13/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6889 - val_loss: 0.5397
# Epoch 14/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6832 - val_loss: 0.5238
# Epoch 15/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6764 - val_loss: 0.5052
# Epoch 16/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6709 - val_loss: 0.4903
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6663 - val_loss: 0.4859
# Epoch 18/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6614 - val_loss: 0.4832
# Epoch 19/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6579 - val_loss: 0.4791
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6529 - val_loss: 0.4709
# Epoch 21/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6486 - val_loss: 0.4713
# Epoch 22/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6446 - val_loss: 0.4690
# Epoch 23/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6403 - val_loss: 0.4577
# Epoch 24/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6359 - val_loss: 0.4519
# Epoch 25/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6324 - val_loss: 0.4466
# Epoch 26/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6285 - val_loss: 0.4462
# Epoch 27/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6252 - val_loss: 0.4384
# Epoch 28/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6218 - val_loss: 0.4297
# Epoch 29/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6181 - val_loss: 0.4325
# Epoch 30/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6153 - val_loss: 0.4316
# Epoch 31/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6120 - val_loss: 0.4279
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6091 - val_loss: 0.4217
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6063 - val_loss: 0.4154
# Epoch 34/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6033 - val_loss: 0.4159
# Epoch 35/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6009 - val_loss: 0.4173
# Epoch 36/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5974 - val_loss: 0.4105
# Epoch 37/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5947 - val_loss: 0.4084
# Epoch 38/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5922 - val_loss: 0.4027
# Epoch 39/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5900 - val_loss: 0.3978
# Epoch 40/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5873 - val_loss: 0.3979
# Epoch 41/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5852 - val_loss: 0.4000
# Epoch 42/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5828 - val_loss: 0.3973
# Epoch 43/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5806 - val_loss: 0.3986
# Epoch 44/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5784 - val_loss: 0.3992
# Epoch 45/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5763 - val_loss: 0.3970
# Epoch 46/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5754 - val_loss: 0.4028
# Epoch 47/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5727 - val_loss: 0.3997
# Epoch 48/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5708 - val_loss: 0.3964
# Epoch 49/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5694 - val_loss: 0.3854
# Epoch 50/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5678 - val_loss: 0.3828
# Epoch 51/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5662 - val_loss: 0.3864
# Epoch 52/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5642 - val_loss: 0.3893
# Epoch 53/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5620 - val_loss: 0.3857
# Epoch 54/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5612 - val_loss: 0.3769
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5591 - val_loss: 0.3799
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5575 - val_loss: 0.3816
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5565 - val_loss: 0.3836
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5553 - val_loss: 0.3809
# Epoch 59/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5541 - val_loss: 0.3793
# Epoch 60/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5540 - val_loss: 0.3924
# Epoch 61/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5519 - val_loss: 0.3896
# Epoch 62/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5510 - val_loss: 0.3932
# Epoch 63/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5505 - val_loss: 0.3824
# Epoch 64/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5483 - val_loss: 0.3752
# Epoch 65/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5471 - val_loss: 0.3754
# Epoch 66/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5458 - val_loss: 0.3851
# Epoch 67/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5450 - val_loss: 0.3790
# Epoch 68/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5440 - val_loss: 0.3754
# Epoch 69/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5433 - val_loss: 0.3776
# Epoch 70/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5424 - val_loss: 0.3733
# Epoch 71/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5419 - val_loss: 0.3709
# Epoch 72/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5410 - val_loss: 0.3770
# Epoch 73/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5397 - val_loss: 0.3698
# Epoch 74/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5384 - val_loss: 0.3717
# Epoch 75/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5379 - val_loss: 0.3682
# Epoch 76/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5373 - val_loss: 0.3706
# Epoch 77/100
# 13/13 [==============================] - ETA: 0s - loss: 0.447 - 0s 7ms/step - loss: 0.5363 - val_loss: 0.3737
# Epoch 78/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5355 - val_loss: 0.3688
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5344 - val_loss: 0.3666
# Epoch 80/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5341 - val_loss: 0.3707
# Epoch 81/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5336 - val_loss: 0.3725
# Epoch 82/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5332 - val_loss: 0.3615
# Epoch 83/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5318 - val_loss: 0.3646
# Epoch 84/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5309 - val_loss: 0.3688
# Epoch 85/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5304 - val_loss: 0.3718
# Epoch 86/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5295 - val_loss: 0.3761
# Epoch 87/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5294 - val_loss: 0.3807
# Epoch 88/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5287 - val_loss: 0.3794
# Epoch 89/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5282 - val_loss: 0.3792
# Epoch 90/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5275 - val_loss: 0.3698
# Epoch 91/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5270 - val_loss: 0.3664
# Epoch 92/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5261 - val_loss: 0.3604
# Epoch 93/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5261 - val_loss: 0.3646
# Epoch 94/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5254 - val_loss: 0.3620
# Epoch 95/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5247 - val_loss: 0.3608
# Epoch 96/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5249 - val_loss: 0.3642
# Epoch 97/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5240 - val_loss: 0.3662
# Epoch 98/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5235 - val_loss: 0.3617
# Epoch 99/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5230 - val_loss: 0.3657
# Epoch 100/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5222 - val_loss: 0.3690
# MAE: 69.832, MSE: 7090.203, RMSE: 84.203, CVRMSE: 19.781, MAPE: 25.783

# %% [markdown]
# ###  GRU model

# %%
X, Y = generate_time_series_for_rnn_fn(parking_scaled_df, flow_scaled_df, 12, T=1)

# %%
n_train_samples = round(X.shape[0] * training_rate)
X_train = X[:n_train_samples]
y_train = Y[:n_train_samples]

X_valid = X[n_train_samples:]
y_valid = Y[n_train_samples:]

# %%
X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((390, 12, 1), (390, 12, 1), (43, 12, 1), (43, 12, 1))

# %%
y_train[0]
# Out:
# array([[-1.47778221],
#        [-0.71803673],
#        [-0.33845197],
#        [-0.63905714],
#        [-1.20233915],
#        [-1.47972296],
#        [-1.37928042],
#        [-0.66823939],
#        [ 0.07456829],
#        [ 0.69192165],
#        [ 0.85900859],
#        [ 0.93845406]])

# %%
np.random.seed(42)
tf.random.set_seed(42)

model_gru = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True,  input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10)),
    keras.layers.Dense(1)
])

model_gru.compile(loss="mse", optimizer="adam")
history = model_gru.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 4s 87ms/step - loss: 0.9945 - val_loss: 1.1563
# Epoch 2/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.9359 - val_loss: 1.0627
# Epoch 3/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.8595 - val_loss: 0.9398
# Epoch 4/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.8019 - val_loss: 0.7779
# Epoch 5/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.7292 - val_loss: 0.6826
# Epoch 6/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.7100 - val_loss: 0.6385
# Epoch 7/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.6754 - val_loss: 0.6101
# Epoch 8/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.6330 - val_loss: 0.5584
# Epoch 9/100
# 13/13 [==============================] - 0s 19ms/step - loss: 0.5878 - val_loss: 0.5062
# Epoch 10/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.5792 - val_loss: 0.4902
# Epoch 11/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.5517 - val_loss: 0.4413
# Epoch 12/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.5192 - val_loss: 0.4246
# Epoch 13/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4947 - val_loss: 0.4061
# Epoch 14/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.4641 - val_loss: 0.3914
# Epoch 15/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.4839 - val_loss: 0.3931
# Epoch 16/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.4442 - val_loss: 0.3992
# Epoch 17/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.4480 - val_loss: 0.3667
# Epoch 18/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.4014 - val_loss: 0.3548
# Epoch 19/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.4148 - val_loss: 0.3460
# Epoch 20/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.4192 - val_loss: 0.3344
# Epoch 21/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.3800 - val_loss: 0.3163
# Epoch 22/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.4118 - val_loss: 0.3123
# Epoch 23/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3583 - val_loss: 0.3023
# Epoch 24/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3755 - val_loss: 0.2992
# Epoch 25/100
# 13/13 [==============================] - 0s 27ms/step - loss: 0.3474 - val_loss: 0.2849
# Epoch 26/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.3473 - val_loss: 0.2810
# Epoch 27/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3389 - val_loss: 0.2823
# Epoch 28/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3414 - val_loss: 0.2874
# Epoch 29/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3605 - val_loss: 0.2878
# Epoch 30/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3302 - val_loss: 0.2710
# Epoch 31/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3239 - val_loss: 0.2833
# Epoch 32/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.3390 - val_loss: 0.2613
# Epoch 33/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3370 - val_loss: 0.2614
# Epoch 34/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.3311 - val_loss: 0.2708
# Epoch 35/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3232 - val_loss: 0.2622
# Epoch 36/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3152 - val_loss: 0.2498
# Epoch 37/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3225 - val_loss: 0.2676
# Epoch 38/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3050 - val_loss: 0.2525
# Epoch 39/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2981 - val_loss: 0.2608
# Epoch 40/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3098 - val_loss: 0.2566
# Epoch 41/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3199 - val_loss: 0.2520
# Epoch 42/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2944 - val_loss: 0.2470
# Epoch 43/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3107 - val_loss: 0.2613
# Epoch 44/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2987 - val_loss: 0.2412
# Epoch 45/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3150 - val_loss: 0.2473
# Epoch 46/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.3201 - val_loss: 0.2540
# Epoch 47/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2964 - val_loss: 0.2394
# Epoch 48/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.3029 - val_loss: 0.2542
# Epoch 49/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3047 - val_loss: 0.2493
# Epoch 50/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2976 - val_loss: 0.2501
# Epoch 51/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2964 - val_loss: 0.2577
# Epoch 52/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2924 - val_loss: 0.2381
# Epoch 53/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3096 - val_loss: 0.2454
# Epoch 54/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2753 - val_loss: 0.2389
# Epoch 55/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2872 - val_loss: 0.2435
# Epoch 56/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2784 - val_loss: 0.2466
# Epoch 57/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2827 - val_loss: 0.2391
# Epoch 58/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2868 - val_loss: 0.2425
# Epoch 59/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2888 - val_loss: 0.2402
# Epoch 60/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2820 - val_loss: 0.2419
# Epoch 61/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3002 - val_loss: 0.2465
# Epoch 62/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2849 - val_loss: 0.2384
# Epoch 63/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2780 - val_loss: 0.2338
# Epoch 64/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2868 - val_loss: 0.2405
# Epoch 65/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2803 - val_loss: 0.2400
# Epoch 66/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2720 - val_loss: 0.2323
# Epoch 67/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2718 - val_loss: 0.2321
# Epoch 68/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2809 - val_loss: 0.2434
# Epoch 69/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2846 - val_loss: 0.2287
# Epoch 70/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.2635 - val_loss: 0.2340
# Epoch 71/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2678 - val_loss: 0.2355
# Epoch 72/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2785 - val_loss: 0.2435
# Epoch 73/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2818 - val_loss: 0.2328
# Epoch 74/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2755 - val_loss: 0.2308
# Epoch 75/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2637 - val_loss: 0.2450
# Epoch 76/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2731 - val_loss: 0.2278
# Epoch 77/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2675 - val_loss: 0.2329
# Epoch 78/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2604 - val_loss: 0.2261
# Epoch 79/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2755 - val_loss: 0.2271
# Epoch 80/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2656 - val_loss: 0.2321
# Epoch 81/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2469 - val_loss: 0.2384
# Epoch 82/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2777 - val_loss: 0.2152
# Epoch 83/100
# 13/13 [==============================] - 0s 23ms/step - loss: 0.2688 - val_loss: 0.2266
# Epoch 84/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2545 - val_loss: 0.2317
# Epoch 85/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2592 - val_loss: 0.2228
# Epoch 86/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2558 - val_loss: 0.2235
# Epoch 87/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2696 - val_loss: 0.2231
# Epoch 88/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2556 - val_loss: 0.2447
# Epoch 89/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2662 - val_loss: 0.2120
# Epoch 90/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2536 - val_loss: 0.2196
# Epoch 91/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2423 - val_loss: 0.2125
# Epoch 92/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2560 - val_loss: 0.2125
# Epoch 93/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.2604 - val_loss: 0.2244
# Epoch 94/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.2591 - val_loss: 0.2115
# Epoch 95/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.2432 - val_loss: 0.2153
# Epoch 96/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2468 - val_loss: 0.2105
# Epoch 97/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2517 - val_loss: 0.2200
# Epoch 98/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2534 - val_loss: 0.2076
# Epoch 99/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.2635 - val_loss: 0.2121
# Epoch 100/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.2314 - val_loss: 0.2186

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_hat = model_gru.predict(X_valid)

# %%
mae_, mse_, rmse_, cvrmse_, mape_ = compute_metrics_fn(y_valid[:,-1].reshape(-1,), y_hat[:,-1].reshape(-1,), scaler_parking)

print('MAE: {:.3f}, MSE: {:.3f}, RMSE: {:.3f}, CVRMSE: {:.3f}, MAPE: {:.3f}'.format(mae_, mse_, rmse_, cvrmse_, mape_))
# Out:
# MAE: 36.616, MSE: 1815.332, RMSE: 42.607, CVRMSE: 10.005, MAPE: 12.104

# %%
plot_prediction_vs_groundtruth_fn(y_valid, y_hat)

# %% [markdown]
# ------------------------------------

# %%
print("That's all folks!")
# Out:
# That's all folks!
