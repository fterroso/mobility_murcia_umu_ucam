# %% [markdown]
# # Train and test DNN models for parking space prediction

# %%
import pandas as pd
import numpy as np
import os

import tensorflow as tf
from tensorflow import keras

import matplotlib as mpl

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## General functions

# %%
def read_clean_subflows_fn(critera):
    subflows= {}
    for c in critera:
        df = pd.read_csv(os.path.join('data', 'INE_subflows','flow_criterion_{}_clean.csv'.format(c)),
                       parse_dates=[0], index_col=0)
        subflows[c] = df
    return subflows

# %% [markdown]
# ## Read zones 1 parking data (target variable)

# %%
zone1_df = pd.read_csv(os.path.join('data', 'parkings_JULIO', 'zone1.csv'), sep=';', parse_dates=['recvTime'], index_col='recvTime')

# %%
zone1_df.head()
# Out:
#                            free
# recvTime
# 2020-07-13 10:00:00  167.363636
# 2020-07-13 11:00:00  246.157895
# 2020-07-13 12:00:00  351.465909
# 2020-07-13 13:00:00  404.080000
# 2020-07-13 14:00:00  362.413238

# %%
zone1_df.plot(figsize=(20,3),grid=True);

# %%
target_days = zone1_df.index

# %% [markdown]
# ## Read subflows

# %%
target_criteria = range(6,11)

# %%
mob_flows = read_clean_subflows_fn(target_criteria)

# %% [markdown]
# ## Format data

# %%
n_steps = 12
T_ = 1

# %%
#input: flow(t), flow(t-1), ..,flow(t-prev_hours). output: parking(t+T)
def generate_univariate_time_series_fn(zone_parking, subflow, prev_hours, T=1):
    series = []
    for i in range(0,subflow.shape[0]-prev_hours-T):
        mob_values = subflow[i:i+prev_hours].values
        parking_value = zone_parking.iloc[prev_hours + i +T -1]
        s = np.append(mob_values,parking_value).reshape(-1,prev_hours+1)
        series.append(s)
    series= np.array(series)
    series = series.reshape(series.shape[0],prev_hours+1,1)
    return series

# %%
def generate_univariate_time_series_fn2(zone_parking, subflow, prev_hours, T=1):
    series = []
    for i in range(0,subflow.shape[0]-prev_hours-T):
        mob_values = subflow[i:i+prev_hours].values
        parking_values = zone_parking.iloc[i:(prev_hours + i +T -1)]
        s = np.append(mob_values,parking_values).reshape(-1,prev_hours*2)
        series.append(s)
    series= np.array(series)
    series = series.reshape(series.shape[0],prev_hours*2,1)
    return series

# %%
def generate_time_series_for_rnn_fn(zone_parking, subflow, prev_hours, T=1):
    X= []
    Y= []
    for i in range(0,subflow.shape[0]-prev_hours-T):
        mob_values = subflow[i:i+prev_hours].values
        X.append(mob_values)
        parking_values = zone_parking.iloc[i+T:i+T+prev_hours].values
        Y.append(parking_values)
    X= np.array(X)
    X = X.reshape(X.shape[0],prev_hours,1)
    
    Y= np.array(Y)
    Y = Y.reshape(Y.shape[0],prev_hours,1)
    
    return X,Y

# %% [markdown]
# ### Scale data

# %%
mob_flows[9].loc[target_days].values
# Out:
# array([[1185.58 ],
#        [ 961.939],
#        [ 892.195],
#        [ 945.028],
#        [1397.271],
#        [1069.388],
#        [1185.354],
#        [1092.905],
#        [1209.574],
#        [1173.265],
#        [ 894.198],
#        [ 613.856],
#        [ 423.467],
#        [ 137.226],
#        [ 232.449],
#        [ 114.984],
#        [ 109.987],
#        [ 165.038],
#        [ 153.934],
#        [ 315.905],
#        [ 803.06 ],
#        [1365.527],
#        [1440.795],
#        [1133.412],
#        [1014.254],
#        [ 857.186],
#        [ 901.969],
#        [1100.501],
#        [1379.182],
#        [1250.058],
#        [1113.213],
#        [1250.74 ],
#        [1302.085],
#        [1073.019],
#        [ 758.916],
#        [ 551.752],
#        [ 332.601],
#        [ 153.081],
#        [ 165.657],
#        [ 247.315],
#        [ 149.811],
#        [ 120.532],
#        [ 141.467],
#        [ 315.731],
#        [ 700.188],
#        [1441.687],
#        [1214.143],
#        [1149.938],
#        [1144.031],
#        [1018.274],
#        [1054.536],
#        [1198.95 ],
#        [1074.804],
#        [ 952.964],
#        [1169.222],
#        [1322.358],
#        [1152.243],
#        [1140.229],
#        [1021.179],
#        [ 583.483],
#        [ 608.849],
#        [ 194.172],
#        [ 223.49 ],
#        [ 170.783],
#        [ 146.09 ],
#        [  85.08 ],
#        [ 167.882],
#        [ 327.912],
#        [ 725.358],
#        [1403.959],
#        [1239.518],
#        [1235.074],
#        [1024.753],
#        [ 841.808],
#        [ 784.935],
#        [1009.143],
#        [1322.188],
#        [1096.215],
#        [ 842.873],
#        [1055.028],
#        [1251.797],
#        [1048.203],
#        [ 903.283],
#        [ 685.686],
#        [ 436.846],
#        [ 163.769],
#        [ 170.878],
#        [ 141.803],
#        [  82.511],
#        [ 170.528],
#        [ 198.184],
#        [ 384.06 ],
#        [ 753.722],
#        [1426.685],
#        [1215.6  ],
#        [1350.826],
#        [ 896.63 ],
#        [ 813.   ],
#        [ 802.888],
#        [ 979.922],
#        [1160.289],
#        [1066.984],
#        [1129.841],
#        [1064.886],
#        [ 943.59 ],
#        [1051.041],
#        [ 953.789],
#        [ 637.868],
#        [ 454.011],
#        [ 233.41 ],
#        [ 413.6  ],
#        [ 212.696],
#        [ 108.706],
#        [  83.676],
#        [  97.177],
#        [ 272.261],
#        [ 240.184],
#        [ 234.069],
#        [ 395.001],
#        [ 545.335],
#        [ 599.005],
#        [ 559.448],
#        [ 667.822],
#        [ 644.408],
#        [ 635.122],
#        [ 600.62 ],
#        [ 624.623],
#        [ 786.523],
#        [1014.054],
#        [1100.413],
#        [1024.701],
#        [ 760.743],
#        [ 632.815],
#        [ 348.099],
#        [ 438.5  ],
#        [ 333.161],
#        [ 321.375],
#        [ 190.865],
#        [ 143.448],
#        [ 171.426],
#        [ 155.196],
#        [ 123.106],
#        [ 253.338],
#        [ 354.841],
#        [ 392.278],
#        [ 656.508],
#        [ 569.937],
#        [ 587.437],
#        [ 674.814],
#        [ 652.33 ],
#        [1135.082],
#        [1287.76 ],
#        [1821.192],
#        [2245.356],
#        [1928.264],
#        [1513.138],
#        [ 985.166],
#        [ 446.794],
#        [ 213.207],
#        [ 150.038],
#        [ 135.765],
#        [ 130.429],
#        [ 157.025],
#        [ 419.709],
#        [ 935.692],
#        [1528.067],
#        [1528.048],
#        [1237.115],
#        [1181.146],
#        [ 994.299],
#        [ 963.148],
#        [ 861.29 ],
#        [1500.334],
#        [1195.713],
#        [1156.09 ],
#        [ 981.505],
#        [1122.2  ],
#        [ 911.431],
#        [ 760.732],
#        [ 721.596],
#        [ 433.715],
#        [ 206.987],
#        [ 135.616],
#        [ 145.848],
#        [  69.49 ],
#        [ 127.94 ],
#        [ 166.045],
#        [ 370.422],
#        [ 834.661],
#        [1256.3  ],
#        [1200.874],
#        [1146.917],
#        [ 953.976],
#        [ 814.02 ],
#        [ 831.372],
#        [1030.916],
#        [1211.827],
#        [1120.343],
#        [ 911.355],
#        [1127.786],
#        [1181.959],
#        [1118.57 ],
#        [ 961.431],
#        [ 657.292],
#        [ 517.433],
#        [ 245.393],
#        [ 210.674],
#        [ 145.303],
#        [ 134.034],
#        [  97.773],
#        [ 194.107],
#        [ 314.378],
#        [ 871.592],
#        [1298.592],
#        [1329.382],
#        [1272.327],
#        [1046.835],
#        [ 825.588],
#        [ 713.175],
#        [ 861.593],
#        [1138.824],
#        [1040.086],
#        [ 842.616],
#        [ 989.041],
#        [1102.782],
#        [1212.466],
#        [ 844.095],
#        [ 603.261],
#        [ 411.775],
#        [ 249.911],
#        [ 251.79 ],
#        [  69.648],
#        [  42.216],
#        [ 101.975],
#        [ 146.19 ],
#        [ 309.037],
#        [ 793.773],
#        [1603.941],
#        [1398.311],
#        [1057.279],
#        [ 914.091],
#        [ 883.63 ],
#        [ 875.79 ],
#        [ 916.557],
#        [1060.036],
#        [1111.181],
#        [ 962.694],
#        [1241.88 ],
#        [1044.715],
#        [1188.563],
#        [1040.696],
#        [ 840.067],
#        [ 466.876],
#        [ 226.853],
#        [ 234.877],
#        [ 168.257],
#        [ 105.868],
#        [ 128.146],
#        [ 167.579],
#        [ 305.531],
#        [ 712.526],
#        [1203.413],
#        [1303.258],
#        [1064.156],
#        [ 764.245],
#        [ 841.664],
#        [ 929.345],
#        [ 924.212],
#        [1254.55 ],
#        [ 999.285],
#        [ 866.012],
#        [ 995.288],
#        [ 909.303],
#        [1046.266],
#        [ 857.863],
#        [ 719.688],
#        [ 390.259],
#        [ 182.07 ],
#        [ 276.802],
#        [ 262.703],
#        [ 138.589],
#        [ 126.411],
#        [ 100.713],
#        [ 153.499],
#        [ 371.893],
#        [ 338.071],
#        [ 539.842],
#        [ 551.592],
#        [ 557.898],
#        [ 695.642],
#        [ 609.898],
#        [ 492.186],
#        [ 524.533],
#        [ 467.36 ],
#        [ 586.879],
#        [ 771.741],
#        [ 890.825],
#        [1078.592],
#        [ 897.758],
#        [ 719.221],
#        [ 522.465],
#        [ 287.695],
#        [ 431.723],
#        [ 391.35 ],
#        [ 273.498],
#        [ 117.342],
#        [  47.796],
#        [  91.989],
#        [ 140.836],
#        [ 158.661],
#        [ 209.139],
#        [ 319.072],
#        [ 476.629],
#        [ 461.769],
#        [ 571.425],
#        [ 526.494],
#        [ 586.788],
#        [ 686.563],
#        [ 863.978],
#        [1146.985],
#        [1758.302],
#        [1775.991],
#        [1745.565],
#        [1516.401],
#        [1077.011],
#        [ 415.036],
#        [ 320.683],
#        [ 229.15 ],
#        [ 141.92 ],
#        [ 146.285],
#        [ 217.903],
#        [ 394.189],
#        [ 858.187],
#        [1552.51 ],
#        [1614.019],
#        [1297.874],
#        [1077.919],
#        [ 927.663],
#        [ 826.022],
#        [ 804.102],
#        [1314.62 ],
#        [1066.746],
#        [ 959.547],
#        [1009.805],
#        [1005.729],
#        [ 863.772],
#        [ 740.567],
#        [ 529.42 ],
#        [ 427.854],
#        [ 175.653],
#        [ 166.278],
#        [  70.205],
#        [  88.561],
#        [ 123.043],
#        [ 198.911],
#        [ 353.778],
#        [ 830.179],
#        [1522.247],
#        [1280.029],
#        [1386.287],
#        [1035.321],
#        [ 812.987],
#        [ 833.985],
#        [ 863.036],
#        [1236.631],
#        [1037.512],
#        [ 992.859],
#        [1007.56 ],
#        [1202.22 ],
#        [1009.383],
#        [ 915.621],
#        [ 607.727],
#        [ 419.952],
#        [ 210.696],
#        [ 172.133],
#        [ 134.764],
#        [  93.453],
#        [ 113.369],
#        [ 235.647],
#        [ 292.951],
#        [ 841.114],
#        [1260.802],
#        [1337.502],
#        [1219.564],
#        [ 953.833],
#        [ 746.805],
#        [ 809.447],
#        [ 974.991],
#        [1195.947],
#        [ 889.477],
#        [ 993.861],
#        [1048.935],
#        [1087.34 ],
#        [1103.316],
#        [ 865.25 ],
#        [ 695.225],
#        [ 460.716],
#        [ 142.801],
#        [ 166.641],
#        [ 175.338],
#        [ 102.529],
#        [ 154.658],
#        [ 164.358],
#        [ 434.313],
#        [ 897.658],
#        [1496.207],
#        [1216.2  ],
#        [1236.618],
#        [1024.638],
#        [ 859.849],
#        [ 719.604],
#        [ 961.123],
#        [ 971.695],
#        [1046.266],
#        [ 974.048],
#        [ 858.887],
#        [ 946.972],
#        [ 998.615],
#        [ 745.078],
#        [ 661.93 ],
#        [ 511.777],
#        [ 190.844],
#        [ 257.501],
#        [ 142.13 ],
#        [  99.529],
#        [ 141.45 ],
#        [ 170.597],
#        [ 301.732],
#        [ 733.018],
#        [1484.503],
#        [1244.96 ],
#        [1001.594],
#        [ 886.412],
#        [ 869.008],
#        [ 851.071],
#        [ 850.25 ],
#        [1129.446],
#        [ 986.778],
#        [ 740.718],
#        [ 871.318],
#        [1006.084],
#        [ 798.871],
#        [ 717.623],
#        [ 584.087],
#        [ 410.659],
#        [ 143.444]])

# %%
scaler_flow =  StandardScaler()
flow_scaled = scaler_flow.fit_transform(mob_flows[9].loc[target_days].values)
flow_scaled_df = pd.DataFrame(flow_scaled)
flow_scaled_df.head()
# Out:
#           0
# 0  1.050581
# 1  0.537342
# 2  0.377285
# 3  0.498533
# 4  1.536396

# %%
scaler_parking =  StandardScaler()
zone_scaled =scaler_parking.fit_transform(zone1_df.values)
parking_scaled_df = pd.DataFrame(zone_scaled)
parking_scaled_df.head()
# Out:
#           0
# 0 -2.046244
# 1 -1.477782
# 2 -0.718037
# 3 -0.338452
# 4 -0.639057

# %% [markdown]
# ### Generate time series samples

# %%
ts = generate_univariate_time_series_fn2(parking_scaled_df, flow_scaled_df, n_steps, T_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-ab2e3c816efe> in <module>
# ----> 1 ts = generate_univariate_time_series_fn2(parking_scaled_df, flow_scaled_df, n_steps, T_)
#
# <ipython-input-56-2c6a0b7ecb35> in generate_univariate_time_series_fn2(zone_parking, subflow, prev_hours, T)
#       4         mob_values = subflow[i:i+prev_hours].values
#       5         parking_value = zone_parking.iloc[i:(prev_hours + i +T -1)]
# ----> 6         s = np.append(mob_values,parking_value).reshape(-1,prev_hours+1)
#       7         series.append(s)
#       8     series= np.array(series)
#
# ValueError: cannot reshape array of size 24 into shape (13)

# %%
print(ts.shape)
# Out:
# (433, 13, 1)

# %%
n_series = ts.shape[0]

# %% [markdown]
# ## Split training-test

# %%
training_rate = 0.9

# %%
n_series_training = round(n_series * training_rate)

# %%
X_train, y_train = ts[:n_series_training,:n_steps], ts[:n_series_training, -1]
X_valid, y_valid = ts[n_series_training:,:n_steps], ts[n_series_training:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((390, 12, 1), (390, 1))

# %%
X_valid.shape, y_valid.shape
# Out:
# ((43, 12, 1), (43, 1))

# %% [markdown]
# ## Test DNN models

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    #plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    #plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

# %%
def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
def compute_metrics_fn(y_valid, y_hat, scaler):
    ## actual train and test values
    y_hat_resc = scaler_parking.inverse_transform(y_hat)
    y_valid_resc = scaler_parking.inverse_transform(y_valid)

    mae_ = mean_absolute_error(y_valid_resc, y_hat_resc)
    mse_ = mean_squared_error(y_valid_resc, y_hat_resc)
    rmse_ = mean_squared_error(y_valid_resc, y_hat_resc, squared = False)
    cvrmse_ = rmse_/np.mean(y_valid_resc)*100 # it is a percentage
    mape_ = mape(y_valid_resc, y_hat_resc)
    
    return mae_, mse_, rmse_, cvrmse_, mape_

# %%
def plot_prediction_vs_groundtruth_fn(y_valid, y_hat):
    y_hat_resc = scaler_parking.inverse_transform( y_hat[:,-1].reshape(-1,))
    y_valid_resc = scaler_parking.inverse_transform(y_valid[:,-1].reshape(-1,))
    plt.plot(np.arange(len(y_hat_resc)), y_hat_resc, "b.-", label="y_hat")
    plt.plot(np.arange(len(y_valid_resc)), y_valid_resc, "r.-", label="y_true")
    plt.legend(fontsize=14)
    plt.xlabel("Timestamp")
    plt.ylabel("Free places")
    plt.grid(True)

# %% [markdown]
# ### MLP - benchmark

# %%
import tensorflow as tf
from tensorflow import keras

# %%
np.random.seed(42)
tf.random.set_seed(42)

model_mlp = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[n_steps, 1]),
    keras.layers.Dense(1)
])

model_mlp.compile(loss="mse", optimizer="adam")
history = model_mlp.fit(X_train, y_train, epochs=100, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 24ms/step - loss: 1.2167 - val_loss: 1.3824
# Epoch 2/100
# 13/13 [==============================] - 0s 7ms/step - loss: 1.1351 - val_loss: 1.2606
# Epoch 3/100
# 13/13 [==============================] - 0s 6ms/step - loss: 1.0603 - val_loss: 1.1596
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 1.0003 - val_loss: 1.0710
# Epoch 5/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.9568 - val_loss: 0.9869
# Epoch 6/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.9136 - val_loss: 0.9232
# Epoch 7/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.8852 - val_loss: 0.8644
# Epoch 8/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.8609 - val_loss: 0.8215
# Epoch 9/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.8416 - val_loss: 0.7802
# Epoch 10/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.8272 - val_loss: 0.7450
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.8139 - val_loss: 0.7139
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.8016 - val_loss: 0.6853
# Epoch 13/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7912 - val_loss: 0.6699
# Epoch 14/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.7830 - val_loss: 0.6533
# Epoch 15/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7747 - val_loss: 0.6317
# Epoch 16/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.7667 - val_loss: 0.6166
# Epoch 17/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7600 - val_loss: 0.6086
# Epoch 18/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7533 - val_loss: 0.6024
# Epoch 19/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.7477 - val_loss: 0.5925
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7405 - val_loss: 0.5825
# Epoch 21/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7345 - val_loss: 0.5752
# Epoch 22/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.7279 - val_loss: 0.5711
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7218 - val_loss: 0.5574
# Epoch 24/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7160 - val_loss: 0.5484
# Epoch 25/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.7106 - val_loss: 0.5464
# Epoch 26/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7054 - val_loss: 0.5441
# Epoch 27/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.7008 - val_loss: 0.5305
# Epoch 28/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6952 - val_loss: 0.5192
# Epoch 29/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6900 - val_loss: 0.5194
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6853 - val_loss: 0.5142
# Epoch 31/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6810 - val_loss: 0.5100
# Epoch 32/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6766 - val_loss: 0.5025
# Epoch 33/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6720 - val_loss: 0.4974
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.6676 - val_loss: 0.4945
# Epoch 35/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6635 - val_loss: 0.4938
# Epoch 36/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6587 - val_loss: 0.4846
# Epoch 37/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6545 - val_loss: 0.4828
# Epoch 38/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6506 - val_loss: 0.4752
# Epoch 39/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6467 - val_loss: 0.4690
# Epoch 40/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6428 - val_loss: 0.4665
# Epoch 41/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6391 - val_loss: 0.4689
# Epoch 42/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6356 - val_loss: 0.4655
# Epoch 43/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6321 - val_loss: 0.4667
# Epoch 44/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.6288 - val_loss: 0.4649
# Epoch 45/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6255 - val_loss: 0.4620
# Epoch 46/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.6233 - val_loss: 0.4661
# Epoch 47/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6197 - val_loss: 0.4630
# Epoch 48/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6169 - val_loss: 0.4575
# Epoch 49/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6145 - val_loss: 0.4494
# Epoch 50/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6119 - val_loss: 0.4490
# Epoch 51/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6094 - val_loss: 0.4457
# Epoch 52/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.6066 - val_loss: 0.4443
# Epoch 53/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6035 - val_loss: 0.4355
# Epoch 54/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6019 - val_loss: 0.4270
# Epoch 55/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5990 - val_loss: 0.4304
# Epoch 56/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5968 - val_loss: 0.4315
# Epoch 57/100
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5951 - val_loss: 0.4328
# Epoch 58/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5930 - val_loss: 0.4303
# Epoch 59/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5912 - val_loss: 0.4264
# Epoch 60/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5900 - val_loss: 0.4361
# Epoch 61/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.5877 - val_loss: 0.4357
# Epoch 62/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5861 - val_loss: 0.4397
# Epoch 63/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.5853 - val_loss: 0.4299
# Epoch 64/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5826 - val_loss: 0.4244
# Epoch 65/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5807 - val_loss: 0.4212
# Epoch 66/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5792 - val_loss: 0.4281
# Epoch 67/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5777 - val_loss: 0.4206
# Epoch 68/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5761 - val_loss: 0.4172
# Epoch 69/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5750 - val_loss: 0.4204
# Epoch 70/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5739 - val_loss: 0.4146
# Epoch 71/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5727 - val_loss: 0.4119
# Epoch 72/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5712 - val_loss: 0.4140
# Epoch 73/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5698 - val_loss: 0.4046
# Epoch 74/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5679 - val_loss: 0.4050
# Epoch 75/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5669 - val_loss: 0.4019
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5661 - val_loss: 0.4031
# Epoch 77/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5648 - val_loss: 0.4068
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5637 - val_loss: 0.4006
# Epoch 79/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5623 - val_loss: 0.3970
# Epoch 80/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5614 - val_loss: 0.4019
# Epoch 81/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5601 - val_loss: 0.4015
# Epoch 82/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5598 - val_loss: 0.3907
# Epoch 83/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5581 - val_loss: 0.3968
# Epoch 84/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5572 - val_loss: 0.4005
# Epoch 85/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5563 - val_loss: 0.3992
# Epoch 86/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5549 - val_loss: 0.4014
# Epoch 87/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5546 - val_loss: 0.4073
# Epoch 88/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5538 - val_loss: 0.4075
# Epoch 89/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5528 - val_loss: 0.4045
# Epoch 90/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5518 - val_loss: 0.3942
# Epoch 91/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5511 - val_loss: 0.3903
# Epoch 92/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5500 - val_loss: 0.3853
# Epoch 93/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5499 - val_loss: 0.3889
# Epoch 94/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5490 - val_loss: 0.3853
# Epoch 95/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5480 - val_loss: 0.3858
# Epoch 96/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5479 - val_loss: 0.3890
# Epoch 97/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5470 - val_loss: 0.3926
# Epoch 98/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5463 - val_loss: 0.3906
# Epoch 99/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5458 - val_loss: 0.3933
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 0.5447 - val_loss: 0.3932

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_hat = model_mlp.predict(X_valid)

# %% [markdown]
# #### Get metrics

# %%
mae_, mse_, rmse_, cvrmse_, mape_ = compute_metrics_fn(y_valid, y_hat, scaler_parking)

print('MAE: {:.3f}, MSE: {:.3f}, RMSE: {:.3f}, CVRMSE: {:.3f}, MAPE: {:.3f}'.format(mae_, mse_, rmse_, cvrmse_, mape_))
# Out:
# MAE: 73.932, MSE: 7553.531, RMSE: 86.911, CVRMSE: 20.408, MAPE: 26.495

# %%
plot_prediction_vs_groundtruth_fn(y_valid, y_hat)

# %% [markdown]
# ###  GRU model

# %%
X, Y = generate_time_series_for_rnn_fn(parking_scaled_df, flow_scaled_df, 12, T=1)

# %%
n_train_samples = round(X.shape[0] * training_rate)
X_train = X[:n_train_samples]
y_train = Y[:n_train_samples]

X_valid = X[n_train_samples:]
y_valid = Y[n_train_samples:]

# %%
X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((390, 12, 1), (390, 12, 1), (43, 12, 1), (43, 12, 1))

# %%
np.random.seed(42)
tf.random.set_seed(42)

model_gru = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True,  input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10)),
    keras.layers.Dense(1)
])

model_gru.compile(loss="mse", optimizer="adam")
history = model_gru.fit(X_train, y_train, epochs=50, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 2s 152ms/step - loss: 0.9798 - val_loss: 1.1563
# Epoch 2/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.9172 - val_loss: 1.0627
# Epoch 3/50
# 13/13 [==============================] - 0s 33ms/step - loss: 0.8545 - val_loss: 0.9398
# Epoch 4/50
# 13/13 [==============================] - 0s 31ms/step - loss: 0.7732 - val_loss: 0.7779
# Epoch 5/50
# 13/13 [==============================] - 0s 36ms/step - loss: 0.7249 - val_loss: 0.6826
# Epoch 6/50
# 13/13 [==============================] - 0s 30ms/step - loss: 0.6890 - val_loss: 0.6385
# Epoch 7/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.6574 - val_loss: 0.6101
# Epoch 8/50
# 13/13 [==============================] - 0s 32ms/step - loss: 0.6265 - val_loss: 0.5584
# Epoch 9/50
# 13/13 [==============================] - 0s 31ms/step - loss: 0.5981 - val_loss: 0.5062
# Epoch 10/50
# 13/13 [==============================] - 0s 29ms/step - loss: 0.5668 - val_loss: 0.4902
# Epoch 11/50
# 13/13 [==============================] - 0s 25ms/step - loss: 0.5364 - val_loss: 0.4413
# Epoch 12/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.5095 - val_loss: 0.4246
# Epoch 13/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.4901 - val_loss: 0.4061
# Epoch 14/50
# 13/13 [==============================] - 0s 27ms/step - loss: 0.4777 - val_loss: 0.3914
# Epoch 15/50
# 13/13 [==============================] - 0s 33ms/step - loss: 0.4653 - val_loss: 0.3931
# Epoch 16/50
# 13/13 [==============================] - 0s 31ms/step - loss: 0.4536 - val_loss: 0.3992
# Epoch 17/50
# 13/13 [==============================] - 0s 30ms/step - loss: 0.4537 - val_loss: 0.3667
# Epoch 18/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.4329 - val_loss: 0.3548
# Epoch 19/50
# 13/13 [==============================] - 0s 30ms/step - loss: 0.4196 - val_loss: 0.3460
# Epoch 20/50
# 13/13 [==============================] - 0s 26ms/step - loss: 0.4070 - val_loss: 0.3344
# Epoch 21/50
# 13/13 [==============================] - 0s 33ms/step - loss: 0.3932 - val_loss: 0.3163
# Epoch 22/50
# 13/13 [==============================] - 0s 30ms/step - loss: 0.3855 - val_loss: 0.3123
# Epoch 23/50
# 13/13 [==============================] - 0s 25ms/step - loss: 0.3737 - val_loss: 0.3023
# Epoch 24/50
# 13/13 [==============================] - 0s 27ms/step - loss: 0.3649 - val_loss: 0.2992
# Epoch 25/50
# 13/13 [==============================] - 0s 26ms/step - loss: 0.3574 - val_loss: 0.2849
# Epoch 26/50
# 13/13 [==============================] - 0s 26ms/step - loss: 0.3505 - val_loss: 0.2810
# Epoch 27/50
# 13/13 [==============================] - 0s 24ms/step - loss: 0.3501 - val_loss: 0.2823
# Epoch 28/50
# 13/13 [==============================] - 0s 23ms/step - loss: 0.3473 - val_loss: 0.2874
# Epoch 29/50
# 13/13 [==============================] - 0s 12ms/step - loss: 0.3443 - val_loss: 0.2878
# Epoch 30/50
# 13/13 [==============================] - 0s 22ms/step - loss: 0.3402 - val_loss: 0.2710
# Epoch 31/50
# 13/13 [==============================] - 0s 30ms/step - loss: 0.3379 - val_loss: 0.2833
# Epoch 32/50
# 13/13 [==============================] - 0s 28ms/step - loss: 0.3335 - val_loss: 0.2613
# Epoch 33/50
# 13/13 [==============================] - 0s 28ms/step - loss: 0.3296 - val_loss: 0.2614
# Epoch 34/50
# 13/13 [==============================] - 0s 21ms/step - loss: 0.3303 - val_loss: 0.2708
# Epoch 35/50
# 13/13 [==============================] - 0s 14ms/step - loss: 0.3250 - val_loss: 0.2622
# Epoch 36/50
# 13/13 [==============================] - 0s 32ms/step - loss: 0.3260 - val_loss: 0.2498
# Epoch 37/50
# 13/13 [==============================] - 0s 25ms/step - loss: 0.3258 - val_loss: 0.2676
# Epoch 38/50
# 13/13 [==============================] - 0s 34ms/step - loss: 0.3161 - val_loss: 0.2525
# Epoch 39/50
# 13/13 [==============================] - 0s 24ms/step - loss: 0.3156 - val_loss: 0.2608
# Epoch 40/50
# 13/13 [==============================] - 0s 19ms/step - loss: 0.3129 - val_loss: 0.2566
# Epoch 41/50
# 13/13 [==============================] - 0s 13ms/step - loss: 0.3108 - val_loss: 0.2520
# Epoch 42/50
# 13/13 [==============================] - 0s 31ms/step - loss: 0.3085 - val_loss: 0.2470
# Epoch 43/50
# 13/13 [==============================] - 0s 29ms/step - loss: 0.3078 - val_loss: 0.2613
# Epoch 44/50
# 13/13 [==============================] - 0s 26ms/step - loss: 0.3075 - val_loss: 0.2412
# Epoch 45/50
# 13/13 [==============================] - 0s 27ms/step - loss: 0.3055 - val_loss: 0.2473
# Epoch 46/50
# 13/13 [==============================] - 0s 15ms/step - loss: 0.3057 - val_loss: 0.2540
# Epoch 47/50
# 13/13 [==============================] - 0s 24ms/step - loss: 0.3016 - val_loss: 0.2394
# Epoch 48/50
# 13/13 [==============================] - 0s 30ms/step - loss: 0.3011 - val_loss: 0.2542
# Epoch 49/50
# 13/13 [==============================] - 0s 31ms/step - loss: 0.3038 - val_loss: 0.2493
# Epoch 50/50
# 13/13 [==============================] - 0s 29ms/step - loss: 0.2990 - val_loss: 0.2501

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_hat = model_gru.predict(X_valid)

# %%
mae_, mse_, rmse_, cvrmse_, mape_ = compute_metrics_fn(y_valid[:,-1].reshape(-1,), y_hat[:,-1].reshape(-1,), scaler_parking)

print('MAE: {:.3f}, MSE: {:.3f}, RMSE: {:.3f}, CVRMSE: {:.3f}, MAPE: {:.3f}'.format(mae_, mse_, rmse_, cvrmse_, mape_))
# Out:
# MAE: 32.937, MSE: 2030.886, RMSE: 45.065, CVRMSE: 10.582, MAPE: 11.619

# %%
plot_prediction_vs_groundtruth_fn(y_valid, y_hat)

# %% [markdown]
# ------------------------------------

# %%
print("That's all folks!")
# Out:
# That's all folks
